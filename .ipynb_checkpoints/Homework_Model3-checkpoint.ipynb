# %% [markdown]
# ![Model3HomeWork_Question1.png](attachment:Model3HomeWork_Question1.png)

# %% [markdown]
# ![Model3Homework_Question2.1.png](attachment:Model3Homework_Question2.1.png)

# %% [markdown]
# ![Model3Homework_Question2.2.png](attachment:Model3Homework_Question2.2.png)

# %% [markdown]
# ![Model3Homework_Question3.1.png](attachment:Model3Homework_Question3.1.png)

# %% [markdown]
# ![Model3Homework_Question3.2.png](attachment:Model3Homework_Question3.2.png)

# %% [markdown]
# ![Model3Homework_Question4.1.png](attachment:Model3Homework_Question4.1.png)

# %% [markdown]
# ![Model3HomeWork_Question4.2.png](attachment:Model3HomeWork_Question4.2.png)

# %% [markdown]
# ![Model3Homework_Question5.png](attachment:Model3Homework_Question5.png)

# %% [markdown]
# ![Model3Homework_Question6.1.png](attachment:Model3Homework_Question6.1.png)

# %% [markdown]
# ![Model3Homework_Question6.2.png](attachment:Model3Homework_Question6.2.png)
